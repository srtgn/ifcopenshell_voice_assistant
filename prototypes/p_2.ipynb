# %% [markdown]
# # Prototype #2 voice assistant

# %% [markdown]
# ![photo.jpeg](attachment:photo.jpeg)

# %% [markdown]
# ##### Voice recognition

# %%
import numpy
import apiai
import speech_recognition as sr
import ifcopenshell

# %%
model = ifcopenshell.open("C:\\Users\\srate\\repos\\voice_assistant\\prototypes\\data\\ifc_files\\Duplex_A.ifc")
model

# %%
walls = model.by_type("IfcWall")
walls
# Out:
# [#4131=IfcWallStandardCase('2O2Fr$t4X7Zf8NOew3FNld',#33,'Basic Wall:Interior - Partition (92mm Stud):138584',$,'Basic Wall:Interior - Partition (92mm Stud):128360',#4118,#4130,'138584'),
#  #4287=IfcWallStandardCase('2O2Fr$t4X7Zf8NOew3FNbT',#33,'Basic Wall:Party Wall - CMU Residential Unit Dimising Wall:139234',$,'Basic Wall:Party Wall - CMU Residential Unit Dimising Wall:128555',#4251,#4286,'139234'),
#  #4399=IfcWallStandardCase('2O2Fr$t4X7Zf8NOew3FKRi',#33,'Basic Wall:Party Wall - CMU Residential Unit Dimising Wall:139347',$,'Basic Wall:Party Wall - CMU Residential Unit Dimising Wall:128555',#4364,#4398,'139347'),
#  #4465=IfcWallStandardCase('2O2Fr$t4X7Zf8NOew3FKRH',#33,'Basic Wall:Party Wall - CMU Residential Unit Dimising Wall:139374',$,'Basic Wall:Party Wall - CMU Residential Unit Dimising Wall:128555',#4430,#4464,'139374'),
# ...

# %%
r = sr.Recognizer()
mic = sr.Microphone()
with mic as source:
    r.adjust_for_ambient_noise(source, duration=1)
    audio = r.listen(source)
    
r.recognize_google(audio)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-91-4269d3a859cd> in <module>
#       3 with mic as source:
#       4     r.adjust_for_ambient_noise(source, duration=1)
# ----> 5     audio = r.listen(source)
#       6
#       7 r.recognize_google(audio)
#
# ~\miniconda3\envs\va\lib\site-packages\speech_recognition\__init__.py in listen(self, source, timeout, phrase_time_limit, snowboy_configuration)
#     650                     break
#     651
# --> 652                 buffer = source.stream.read(source.CHUNK)
#     653                 if len(buffer) == 0: break  # reached end of the stream
#     654                 frames.append(buffer)
#
# ~\miniconda3\envs\va\lib\site-packages\speech_recognition\__init__.py in read(self, size)
#     159
#     160         def read(self, size):
# ...

# %% [markdown]
# #### Example #1 Opening the ifc file

# %%
from IPython.display import Video

video_1 = Video('./data/videos/1.mp4', html_attributes="autoplay")
video_1
# Out:
# <video src="./data/videos/1.mp4" autoplay  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
text = "open the file"

# %% [markdown]
# ##### NLP

# %% [markdown]
# ![photo2.jpeg](attachment:WhatsApp%20Image%202021-12-14%20at%202.14.15%20PM.jpeg)

# %%
def trigger_finder(text, commands):
    word_set = set(commands)
    phrase_set = set(text.split())
    if word_set.intersection(phrase_set):
        trigger = word_set.intersection(phrase_set)
        return trigger

# %%
commands = ['open', 'create', 'delete']

# %%
trigger = trigger_finder(text, commands)
trigger
# Out:
# {'open'}

# %% [markdown]
# ##### IFC

# %%
import os
os.startfile("C:\Users\srate\repos\voice_assistant\RWTHViewer\RWTHViewer\RWTHViewer.exe")
# Out:
#   File "<ipython-input-1-0e42c46f1df6>", line 2
#     os.startfile("C:\Users\srate\repos\voice_assistant\RWTHViewer\RWTHViewer\RWTHViewer.exe")
#                 ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
if trigger == "open":
    ifc_viewer_command = ifcopenshell.open("./hello_reiff_2021.ifc")

# %%
# %%html
# <iframe src="https://www.ifcviewer.de/?id=61b65bb84f88c63620163c0a&file=hello_reiff_2021.ifc" width="520" height="500"></iframe>

# %% [markdown]
# Mit der in diesem Notebook verfügbaren Helfer-Klasssen `JupyterIFCRenderer` kann das geladene Modell eingebettet im Notebook angezeigt werden.

# %%
from utils.JupyterIFCRenderer import JupyterIFCRenderer
viewer = JupyterIFCRenderer(m, size=(400,300))
viewer

# %% [markdown]
# #### Example #2 Changing the wall's color

# %%
from IPython.display import Video

# Video("test.mp4")
video_1 = Video('./data/videos/2.mp4', html_attributes="autoplay")
video_1
# Out:
# <video src="./data/videos/2.mp4" autoplay  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
text = 'change the color to green'

# %%
colors = ['red', 'blue', 'green']

# %%
trigger = trigger_finder(text, colors)
trigger
# Out:
# {'green'}

# %%
color = 'green'

# %%
if color is 'green':
    for p in m.by_type("IfcProduct"):
        viewer.setColorProduct(p, "#00BB0B")

# %%
viewer

# %% [markdown]
# #### Example #3 Changing the view's size

# %%
from IPython.display import Video

# Video("test.mp4")
video_1 = Video('./data/videos/3.mp4', html_attributes="autoplay")
video_1

# %%
text = 'double the size of the viwer'

# %%
viewer_size = ['double', 'triple', 'half']

# %%
trigger = trigger_finder(text, viewer_size)
trigger

# %%
viewer = JupyterIFCRenderer(m, size=(800,600))
viewer
